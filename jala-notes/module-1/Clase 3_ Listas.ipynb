# %% [markdown]
# ### Ejercicio 1: La Maleta de Aventuras de Juan
# Juan está a punto de embarcarse en un viaje emocionante.
# Antes de salir, necesita asegurarse de que tiene todo lo que necesita en su maleta.
# Hay un artículo en particular, como una chaqueta, que es esencial para su aventura.
# Tu tarea es ayudar a Juan a verificar si la chaqueta está en su maleta.

# %%
# los articulos que Juan tiene en su maleta
maleta = ["zapatos", "camisa", "pantalón", "chaqueta"]
# el articulo a buscar
articulo = "chaqueta"

# escribe el resto del codigo aqui

# %% [markdown]
# ### Ejercicio 2: La Mochila de Clara
# Clara está preparando su mochila para la escuela.
# Se da cuenta de que el libro que lleva ya no lo necesita y decide reemplazarlo por su cuaderno favorito.
# Tu tarea es ayudar a Clara a realizar este cambio en su mochila.

# %%
# los articulos que tiene Clara en su mochila
mochila = ["libro", "lápiz", "borrador", "marcadores"]
articulo_a_reemplazar = "libro"
nuevo_articulo = "cuaderno"

# escribe el resto del codigo aqui

# %% [markdown]
# ### Ejercicio 3: La Agenda de Ana
# Ana es muy organizada y mantiene una lista de sus actividades diarias.
# A lo largo del día, Ana decide añadir nuevas actividades o eliminar las que ya ha completado.
# Tu tarea es ayudar a Ana a gestionar su agenda. agregando nuevas actividades a su agenda y eliminando de la agenda las actividades ya completadas

# %%
# la agenda inicial de Ana para hoy
actividades = ["Desayunar", "Ir al gimnasio", "Estudiar", "Comprar comida"]

# Ana completa una actividad
actividad_completada = "Ir al gimnasio"

#escribe aqui el codigo para completar esa actividad



# Ana añade una nueva actividad
nueva_actividad = "Leer un libro"

# escribe aqui el codigo para agregar la nueva actividad
